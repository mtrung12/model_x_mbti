# %%
from pathlib import Path
import sys

import pandas as pd

project_root = Path.cwd().resolve()
if not (project_root / "baselines").exists():
    project_root = (project_root / ".." / "..").resolve()

if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from baselines.evaluate import evaluate
from baselines.predict import predict

# %%
test_df = pd.read_csv(project_root/"data/split/mbti/mini_test.csv")
model_name = "gpt-4o-mini"
temperature = 0
res_dir = str(project_root / "result")
log_dir = str(project_root / "log")
max_new_tokens = 512

train_df = pd.read_csv(project_root/"data/split/mbti/train.csv")

# %%
run_id, run_time, prediction_csv = predict(
    text_df=test_df,
    model_name=model_name,
    log_dir=log_dir,
    prompt_mode="oneshot",
    max_new_tokens=max_new_tokens,
    res_dir=res_dir,
    temperature=temperature,
    example_df=train_df,
)
# Out:
# Loaded 1 records for evaluation using oneshot and gpt-4o-mini.
# Evaluation completed in 4.68 seconds.
# Predictions are saved to F:\std\GR\code\model_x_mbti\result\gpt-4o-mini/oneshot/20260420-164008\predictions.csv

# %%
evaluation = evaluate(
    prediction_csv=prediction_csv,
    model_name=model_name,
    res_dir=res_dir,
    run_time=run_time,
    prompt_mode="oneshot",
    run_id=run_id
)
# Out:
# Loaded predictions from F:\std\GR\code\model_x_mbti\result\gpt-4o-mini/oneshot/20260420-164008\predictions.csv
# Saved evaluation summary to F:\std\GR\code\model_x_mbti\result\gpt-4o-mini/zeroshot/20260420-164008/evaluation_summary.csv
# Saved IE report to F:\std\GR\code\model_x_mbti\result\gpt-4o-mini/zeroshot/20260420-164008/IE_classification_report.txt
# Saved NS report to F:\std\GR\code\model_x_mbti\result\gpt-4o-mini/zeroshot/20260420-164008/NS_classification_report.txt
# Saved TF report to F:\std\GR\code\model_x_mbti\result\gpt-4o-mini/zeroshot/20260420-164008/TF_classification_report.txt
# Saved JP report to F:\std\GR\code\model_x_mbti\result\gpt-4o-mini/zeroshot/20260420-164008/JP_classification_report.txt
